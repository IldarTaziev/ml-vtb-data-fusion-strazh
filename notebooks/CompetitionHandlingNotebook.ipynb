# %%
import os
import getpass
from google.colab import drive

# Монтируем Google Drive (для постоянного хранения)
drive.mount('/content/drive')

# Создаём папку проекта
project_name = "ml-vtb-data-fusion-strazh"
project_path = f"/content/drive/MyDrive/{project_name}"
os.makedirs(project_path, exist_ok=True)
os.chdir(project_path)

# Создаём структуру папок
for dir_name in ["notebooks", "src", "data", "models", "submissions", "reports"]:
    os.makedirs(dir_name, exist_ok=True)

# Настраиваем Git
# !git config --global user.name "IldarTaziev"
# !git config --global user.email "taziev.03@gmail.com"

# Вводим токен (безопасно, через getpass)
token = getpass.getpass('введите token - ')

# Клонируем репозиторий (если он пустой, просто свяжемся)
# !git clone https://github.com/IldarTaziev/{project_name}.git temp_repo
# !cp -r temp_repo/. .  # копируем файлы (README, .gitignore)
# !rm -rf temp_repo

# Настраиваем remote с токеном
# !git remote set-url origin https://{token}@github.com/IldarTaziev/{project_name}.git

# Очищаем токен из переменных
del token

print("✅ Всё готово! Теперь можно работать и коммитить.")
# Out:
# Mounted at /content/drive
# введите token - ··········
# ✅ Всё готово! Теперь можно работать и коммитить.

# %%
commit_msg = input("Опишите, что сделали: ")  # например: "Добавил генерацию признаков по сумме транзакций"

# !git config --global user.name "IldarTaziev"
# !git config --global user.email "taziev.03@gmail.com"

# Делаем коммит и пуш
# !git add .
# !git commit -m "{commit_msg}"
# !git push origin main

print("✅ Изменения загружены на GitHub")
