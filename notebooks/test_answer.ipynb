# %%
# @title Подключение к диску с данными
import os
from google.colab import drive
drive.mount('/content/drive')
# !pip install polars
# !pip install Dask
# !pip install lightgbm
# Out:
# Mounted at /content/drive
# ...

# %%
import polars as pl
df = pl.read_csv("/content/drive/MyDrive/ml-vtb-data-fusion-strazh/data/submission.csv")
print(df.head())
print(df.schema)
print(len(df))
# Out:
# shape: (5, 2)
# ┌─────────────────┬──────────┐
# │ event_id        ┆ predict  │
# │ ---             ┆ ---      │
# │ i64             ┆ f64      │
# ╞═════════════════╪══════════╡
# │ 125485358568070 ┆ 0.002495 │
# │ 124171097275436 ┆ 0.004542 │
# │ 124969959161150 ┆ 0.00233  │
# │ 123200434539489 ┆ 0.002495 │
# │ 125828956511270 ┆ 0.002495 │
# └─────────────────┴──────────┘
# Schema({'event_id': Int64, 'predict': Float64})
# 7610862
