# %%
import os
from google.colab import drive

# Монтируем диск и переходим в проект
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/ml-vtb-data-fusion-strazh')  # укажите свой проект
# Пишем сообщение коммита
commit_msg = input("Опишите, что сделали: ")  # например: "Добавил генерацию признаков по сумме транзакций"

# Делаем коммит и пуш
# !git add .
# !git commit -m "{commit_msg}"
# !git push origin main

print("✅ Изменения загружены на GitHub")
# Out:
# Mounted at /content/drive
# Опишите, что сделали: Добавил структуру проекта
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@f38a7bc1cf5c.(none)')
# Everything up-to-date
# ✅ Изменения загружены на GitHub
