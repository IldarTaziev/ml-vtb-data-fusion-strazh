# %%
# @title Подключение к диску с данными
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd  # или Polars

# Загрузи и проверь
sub = pd.read_csv("/content/drive/MyDrive/ml-vtb-data-fusion-strazh/submissions/submission2.csv")
print(sub.tail())
print("Размер:", sub.shape)
# Out:
#                 event_id   predict
# 7610857  125657156303168 -0.957714
# 7610858  125347920636351 -0.942713
# 7610859  123492494052712 -1.007696
# 7610860  125150351552611 -1.053775
# 7610861  126309992594366 -0.838198
# Размер: (7610862, 2)
